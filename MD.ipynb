# %% [markdown]
# # Пример использования Markdown

# %% [markdown]
# Нужно сделать:
#
# 1. Список.
# 2. Риснуок.
# 3. Таблицу.
# 4. Ссылку.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQWIPWMnurbSrVdyghdyj9HOgkCCnqfwfdKfQ&s" width="150" height="150">
#
# <div align="right">
#
# | A | B | C |
# |---|:---:|---|
# | 11 | 22 | 33 |
# | 1000 | 250 | -50 |
#
# <div align="left")
#
# [Ссылка на руководство по Markdown](https://colab.research.google.com/notebooks/markdown_guide.ipynb#scrollTo=Lhfnlq1Surtk)
